# %%
import numpy as np 
from matplotlib import pyplot as plt
import os
from os import path
import h5py

# %%
dir_figs = "equilibration"
os.makedirs(dir_figs, exist_ok=True)

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/Winslow"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
# plt.title(f"Last $T_{{mat}}$ = {Tmat[-1]/kev_to_kelvin:g} KeV")
plt.title("With absorption")
Trad_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Trad.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Tmat.txt"), delimiter=",")
Trad_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Trad.txt"), delimiter=",")
Tmat_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Tmat.txt"), delimiter=",")
plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "o", c='k', label="Till")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "o", c='k')
plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "s", c='g', markersize=5, label="Winslow")
plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "s", c='g', markersize=5)
plt.legend(loc="best")
# plt.xscale("symlog")
plt.ylim(1., 20)
plt.xlim(0, 30)
plt.savefig(os.path.join(dir_figs, "Winslow.png"))
plt.show()
plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_30', 'Eg_31', 'Eg_32', 'Eg_33', 'Eg_34', 'Eg_35', 'Eg_36', 'Eg_37', 'Eg_38', 'Eg_39', 'Eg_4', 'Eg_40', 'Eg_41', 'Eg_42', 'Eg_43', 'Eg_44', 'Eg_45', 'Eg_46', 'Eg_47', 'Eg_48', 'Eg_49', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  50

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/Winslow_no_compton"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
plt.legend(loc="best")
plt.title(f"Last $T_{{mat}}$ = {Tmat[-1]/kev_to_kelvin:g} KeV")
Trad_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Trad_no_compton.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Tmat_no_compton.txt"), delimiter=",")
# Trad_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Trad.txt"), delimiter=",")
# Tmat_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Tmat.txt"), delimiter=",")
plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "o", c='k', label="Till Trad")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "o", c='k', label="Till Tmat")
# plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "+", c='g', label="Winslow Tmat")
# plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "+", c='g', label="Winslow Trad")
# plt.xscale("symlog")
plt.show()
plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_30', 'Eg_31', 'Eg_32', 'Eg_33', 'Eg_34', 'Eg_35', 'Eg_36', 'Eg_37', 'Eg_38', 'Eg_39', 'Eg_4', 'Eg_40', 'Eg_41', 'Eg_42', 'Eg_43', 'Eg_44', 'Eg_45', 'Eg_46', 'Eg_47', 'Eg_48', 'Eg_49', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  50

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/Winslow_only_compton"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
plt.title(f"Without absorption")
Trad_sample = np.loadtxt(path.join("../compton_data", "Winslow_Trad_only_compton.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Winslow_Tmat_only_compton.txt"), delimiter=",")
plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "s", c='g', label="Winslow")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "s", c='g')
# plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "+", c='g', label="Winslow Tmat")
# plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "+", c='g', label="Winslow Trad")
# plt.xscale("symlog")
plt.xlim(0., 5)
plt.ylim(1., 20)
plt.legend(loc="best")
plt.savefig(os.path.join(dir_figs, "Winslow_no_absorption.png"))
plt.show()

plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_30', 'Eg_31', 'Eg_32', 'Eg_33', 'Eg_34', 'Eg_35', 'Eg_36', 'Eg_37', 'Eg_38', 'Eg_39', 'Eg_4', 'Eg_40', 'Eg_41', 'Eg_42', 'Eg_43', 'Eg_44', 'Eg_45', 'Eg_46', 'Eg_47', 'Eg_48', 'Eg_49', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  50

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/Till"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
# plt.title(f"Last $T_{{mat}}$ = {Tmat[-1]/kev_to_kelvin:g} KeV")
# Trad_sample = np.loadtxt(path.join("../compton_data", "Winslow_Trad_only_compton.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Till_Tmat.txt"), delimiter=",")
# Trad_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Trad.txt"), delimiter=",")
# Tmat_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Tmat.txt"), delimiter=",")
# plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "o", c='k', label="Till Trad")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "o", c='k', label="Till")
# plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "+", c='g', label="Winslow Tmat")
# plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "+", c='g', label="Winslow Trad")
plt.xscale("log")
plt.xlim(8e-3, 5)
plt.ylim(2, 10)
plt.legend(loc="best")
plt.savefig(os.path.join(dir_figs, "Till.png"))
plt.show()
plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_30', 'Eg_31', 'Eg_32', 'Eg_33', 'Eg_34', 'Eg_35', 'Eg_36', 'Eg_37', 'Eg_38', 'Eg_39', 'Eg_4', 'Eg_40', 'Eg_41', 'Eg_42', 'Eg_43', 'Eg_44', 'Eg_45', 'Eg_46', 'Eg_47', 'Eg_48', 'Eg_49', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  50

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/Till_no_compton"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
plt.legend(loc="best")
plt.title(f"Last $T_{{mat}}$ = {Tmat[-1]/kev_to_kelvin:g} KeV")
# Trad_sample = np.loadtxt(path.join("../compton_data", "Winslow_Trad_only_compton.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Till_Tmat_no_compton.txt"), delimiter=",")
# Trad_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Trad.txt"), delimiter=",")
# Tmat_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Tmat.txt"), delimiter=",")
# plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "o", c='k', label="Till Trad")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "o", c='k', label="Till Tmat")
# plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "+", c='g', label="Winslow Tmat")
# plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "+", c='g', label="Winslow Trad")
plt.xscale("log")
plt.xlim(8e-3, 5)
plt.show()
plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_30', 'Eg_31', 'Eg_32', 'Eg_33', 'Eg_34', 'Eg_35', 'Eg_36', 'Eg_37', 'Eg_38', 'Eg_39', 'Eg_4', 'Eg_40', 'Eg_41', 'Eg_42', 'Eg_43', 'Eg_44', 'Eg_45', 'Eg_46', 'Eg_47', 'Eg_48', 'Eg_49', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  50

# %%
output_files_path = "/home/itamarg/workspace/RICH/output/WinslowCMMCChange"
path_to_initial_snap = path.join(output_files_path, f"snap_{0}.h5")

snaps = [file for file in os.listdir(output_files_path) if file.endswith(".h5") and file.startswith("snap")]
print(len(snaps), snaps, sep=', ')

num_of_snaps = len(snaps)
num_cells = None
num_groups = None

with h5py.File(path_to_initial_snap) as h5_file:
    print(h5_file.keys())
    num_cells = len(np.array(h5_file["Temperature"]))
    num_groups = len([key for key in h5_file.keys() if "Eg" in key])

assert num_cells == 1

print("num_cells: ", num_cells)
print("num_groups: ", num_groups)

speed_of_light = 2.99792458e10
stefan_boltzman = 5.670374e-5
radiation_constant = 4 * stefan_boltzman / speed_of_light
boltzmann_constant = 1.380649e-16

ev = 1.602176634e-12
kev = 1e3*ev

kev_to_kelvin = kev / boltzmann_constant

Erad = np.ndarray(shape=num_of_snaps)
Trad = np.ndarray(shape=num_of_snaps)
Tmat = np.ndarray(shape=num_of_snaps)
time = np.ndarray(shape=num_of_snaps)

for i in range(num_of_snaps):
    path_to_snap =  path.join(output_files_path, snaps[i])
    with h5py.File(path_to_snap) as h5_file:
        Tmat[i] = h5_file["Temperature"][0]
        Erad[i] = h5_file["Erad"][0]
        Trad[i] = (Erad[i] / radiation_constant)**0.25
        time[i] = h5_file["Time"][0]

plt.plot(time/1e-9, Trad/kev_to_kelvin, '-b', label="Trad")
plt.plot(time/1e-9, Tmat/kev_to_kelvin, '-r', label="Tmat")
plt.grid()
plt.xlabel("t [ns]")
plt.ylabel("T [KeV]")
# plt.title(f"Last $T_{{mat}}$ = {Tmat[-1]/kev_to_kelvin:g} KeV")
plt.title("With absorption")
Trad_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Trad.txt"), delimiter=",")
Tmat_sample = np.loadtxt(path.join("../compton_data", "Till_winslow_Tmat.txt"), delimiter=",")
Trad_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Trad.txt"), delimiter=",")
Tmat_sample_winslow = np.loadtxt(path.join("../compton_data", "Winslow_Tmat.txt"), delimiter=",")
plt.plot(Trad_sample[:,0]/1e-9, Trad_sample[:,1], "o", c='k', label="Till")
plt.plot(Tmat_sample[:,0]/1e-9, Tmat_sample[:,1], "o", c='k')
plt.plot(Tmat_sample_winslow[:,0]/1e-9, Tmat_sample_winslow[:,1], "s", c='g', markersize=5, label="Winslow")
plt.plot(Trad_sample_winslow[:,0]/1e-9, Trad_sample_winslow[:,1], "s", c='g', markersize=5)
plt.legend(loc="best")
# plt.xscale("symlog")
plt.ylim(1., 20)
plt.xlim(0, 30)
# plt.savefig(os.path.join(dir_figs, "Winslow.png"))
plt.show()
plt.close()
# Out:
# 130, ['snap_0.h5', 'snap_1.h5', 'snap_2.h5', 'snap_3.h5', 'snap_4.h5', 'snap_5.h5', 'snap_6.h5', 'snap_7.h5', 'snap_8.h5', 'snap_9.h5', 'snap_10.h5', 'snap_11.h5', 'snap_12.h5', 'snap_13.h5', 'snap_14.h5', 'snap_15.h5', 'snap_16.h5', 'snap_17.h5', 'snap_18.h5', 'snap_19.h5', 'snap_20.h5', 'snap_21.h5', 'snap_22.h5', 'snap_23.h5', 'snap_24.h5', 'snap_25.h5', 'snap_26.h5', 'snap_27.h5', 'snap_28.h5', 'snap_29.h5', 'snap_30.h5', 'snap_31.h5', 'snap_32.h5', 'snap_33.h5', 'snap_34.h5', 'snap_35.h5', 'snap_36.h5', 'snap_37.h5', 'snap_38.h5', 'snap_39.h5', 'snap_40.h5', 'snap_41.h5', 'snap_42.h5', 'snap_43.h5', 'snap_44.h5', 'snap_45.h5', 'snap_46.h5', 'snap_47.h5', 'snap_48.h5', 'snap_49.h5', 'snap_50.h5', 'snap_51.h5', 'snap_52.h5', 'snap_53.h5', 'snap_54.h5', 'snap_55.h5', 'snap_56.h5', 'snap_57.h5', 'snap_58.h5', 'snap_59.h5', 'snap_60.h5', 'snap_61.h5', 'snap_62.h5', 'snap_63.h5', 'snap_64.h5', 'snap_65.h5', 'snap_66.h5', 'snap_67.h5', 'snap_68.h5', 'snap_69.h5', 'snap_70.h5', 'snap_71.h5', 'snap_72.h5', 'snap_73.h5', 'snap_74.h5', 'snap_75.h5', 'snap_76.h5', 'snap_77.h5', 'snap_78.h5', 'snap_79.h5', 'snap_80.h5', 'snap_81.h5', 'snap_82.h5', 'snap_83.h5', 'snap_84.h5', 'snap_85.h5', 'snap_86.h5', 'snap_87.h5', 'snap_88.h5', 'snap_89.h5', 'snap_90.h5', 'snap_91.h5', 'snap_92.h5', 'snap_93.h5', 'snap_94.h5', 'snap_95.h5', 'snap_96.h5', 'snap_97.h5', 'snap_98.h5', 'snap_99.h5', 'snap_100.h5', 'snap_101.h5', 'snap_102.h5', 'snap_103.h5', 'snap_104.h5', 'snap_105.h5', 'snap_106.h5', 'snap_107.h5', 'snap_108.h5', 'snap_109.h5', 'snap_110.h5', 'snap_111.h5', 'snap_112.h5', 'snap_113.h5', 'snap_114.h5', 'snap_115.h5', 'snap_116.h5', 'snap_117.h5', 'snap_118.h5', 'snap_119.h5', 'snap_120.h5', 'snap_121.h5', 'snap_122.h5', 'snap_123.h5', 'snap_124.h5', 'snap_125.h5', 'snap_126.h5', 'snap_127.h5', 'snap_128.h5', 'snap_129.h5']
# <KeysViewHDF5 ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Eg_0', 'Eg_1', 'Eg_10', 'Eg_11', 'Eg_12', 'Eg_13', 'Eg_14', 'Eg_15', 'Eg_16', 'Eg_17', 'Eg_18', 'Eg_19', 'Eg_2', 'Eg_20', 'Eg_21', 'Eg_22', 'Eg_23', 'Eg_24', 'Eg_25', 'Eg_26', 'Eg_27', 'Eg_28', 'Eg_29', 'Eg_3', 'Eg_4', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'stickers', 'tracers']>
# num_cells:  1
# num_groups:  30
